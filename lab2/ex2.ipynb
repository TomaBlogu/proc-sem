# %%
import scipy.io.wavfile
import scipy.signal
import matplotlib.pyplot as plt
import numpy as np
from numpy import size
from scipy import rand

# %%
def sinx(t,faza):
    return 2*np.sin(2*np.pi*400*t + faza)

x1 = np.arange(0,0.003*np.pi,0.00001)
y1 = (sinx(x1,1) + 5*rand(size(x1)))
x2 = np.arange(0,0.003*np.pi,0.00001)
y2 = (sinx(x2,1) + 5*rand(size(x2)))
x3 = np.arange(0,0.003*np.pi,0.00001)
y3 = (sinx(x3,1) + 5*rand(size(x3)))
x4 = np.arange(0,0.003*np.pi,0.00001)
y4 = (sinx(x4,1) + 5*rand(size(x4)))

plt.figure(figsize=(20,5))
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x3,y3)
plt.plot(x4,y4)
