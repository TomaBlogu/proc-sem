# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x1 = lambda t: np.sin(2 * np.pi * 400 * t) # A=1 f=400 faza=0
x2 = lambda t: np.cos(2 * np.pi * 400 * t + np.pi / 2) 
x3 = lambda t: np.cos(2 * np.pi * 400 * t + 2 * np.pi) 
x4 = lambda t: np.cos(2 * np.pi * 400 * t + 3 * np.pi)

# %%
timp = np.linspace(0, 1, 200)
fig, ax = plt.subplots()
fig.suptitle("Sin si cos")
ax.plot(timp, x1(timp))
ax.plot(timp, x2(timp))
ax.plot(timp, x3(timp))
ax.plot(timp, x4(timp))

fig.set_figheight(10)
fig.set_figwidth(20)

# %%
zgomot = np.random.normal(0, 1, 100)
snr = [0.1, 1, 10, 100]
